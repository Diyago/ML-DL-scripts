# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

train.head(5)
# Out:
#   AnimalID     Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945  Hambone  2014-02-12 18:22:00  Return_to_owner            NaN
# 1  A656520    Emily  2013-10-13 12:44:00       Euthanasia      Suffering
# 2  A686464   Pearce  2015-01-31 12:28:00         Adoption         Foster
# 3  A683430      NaN  2014-07-11 19:09:00         Transfer        Partner
# 4  A667013      NaN  2013-11-15 12:52:00         Transfer        Partner
#
#   AnimalType SexuponOutcome AgeuponOutcome                        Breed  \
# 0        Dog  Neutered Male         1 year        Shetland Sheepdog Mix
# 1        Cat  Spayed Female         1 year       Domestic Shorthair Mix
# 2        Dog  Neutered Male        2 years                 Pit Bull Mix
# 3        Cat    Intact Male        3 weeks       Domestic Shorthair Mix
# 4        Dog  Neutered Male        2 years  Lhasa Apso/Miniature Poodle
#
#          Color
# 0  Brown/White
# 1  Cream Tabby
# 2   Blue/White
# 3   Blue Cream
# 4          Tan

# %%
id_test = test['ID'].values # savind id column for later use
test = test.drop(['ID'],axis=1)

# %%
train = train.drop(['AnimalID'],axis=1)

# %%
# fix the DateTime column

def fix_date_time(df):
    def extract_field(_df, start, stop):
        return _df['DateTime'].map(lambda dt: int(dt[start:stop]))
    df['Year'] = extract_field(df,0,4)
    df['Month'] = extract_field(df,5,7)
    df['Day'] = extract_field(df,8,10)
    df['Hour'] = extract_field(df,11,13)
    df['Minute'] = extract_field(df,14,16)
    
    return df.drop(['DateTime'], axis = 1)

train = fix_date_time(train)
test = fix_date_time(test)

# %%
# add a column with a Name frequency count

names = pd.concat([test['Name'], train['Name']])
values = dict(names.value_counts())

train['_NameFreq'] = train['Name'].map(values)
test['_NameFreq'] = test['Name'].map(values)

train['_NameFreq'] = train['_NameFreq'].fillna(-1)
test['_NameFreq'] = test['_NameFreq'].fillna(-1)

print train.head()
print(train.info())
# Out:
#       Name      OutcomeType OutcomeSubtype AnimalType SexuponOutcome  \
# 0  Hambone  Return_to_owner            NaN        Dog  Neutered Male
# 1    Emily       Euthanasia      Suffering        Cat  Spayed Female
# 2   Pearce         Adoption         Foster        Dog  Neutered Male
# 3      NaN         Transfer        Partner        Cat    Intact Male
# 4      NaN         Transfer        Partner        Dog  Neutered Male
#
#   AgeuponOutcome                        Breed        Color  Year  Month  Day  \
# 0         1 year        Shetland Sheepdog Mix  Brown/White  2014      2   12
# 1         1 year       Domestic Shorthair Mix  Cream Tabby  2013     10   13
# 2        2 years                 Pit Bull Mix   Blue/White  2015      1   31
# 3        3 weeks       Domestic Shorthair Mix   Blue Cream  2014      7   11
# 4        2 years  Lhasa Apso/Miniature Poodle          Tan  2013     11   15
#
#    Hour  Minute  _NameFreq
# 0    18      22        6.0
# 1    12      44       25.0
# 2    12      28        2.0
# 3    19       9       -1.0
# 4    12      52       -1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26729 entries, 0 to 26728
# Data columns (total 14 columns):
# Name              19038 non-null object
# OutcomeType       26729 non-null object
# OutcomeSubtype    13117 non-null object
# AnimalType        26729 non-null object
# SexuponOutcome    26728 non-null object
# AgeuponOutcome    26711 non-null object
# Breed             26729 non-null object
# Color             26729 non-null object
# Year              26729 non-null int64
# Month             26729 non-null int64
# Day               26729 non-null int64
# Hour              26729 non-null int64
# Minute            26729 non-null int64
# _NameFreq         26729 non-null float64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 2.9+ MB
# None

# %%
# if name not null make it 1, else 0. If Dog 1, cat 0
train['Name'] = train['Name'].apply(lambda x: 1 if x == x else 0)
train['AnimalType'] = train['AnimalType'].apply(lambda x: 1 if x == 'Dog' else 0)

test['Name'] = test['Name'].apply(lambda x: 1 if x == x else 0)
test['AnimalType'] = test['AnimalType'].apply(lambda x: 1 if x == 'Dog' else 0)

# %%
# label object types. 

from sklearn import preprocessing
lbl = preprocessing.LabelEncoder()

shapeTrain = train.shape[0]
shapeTest = test.shape[0]
train = train.append(test)

toTransform = ['Breed', 'Color', 'SexuponOutcome','OutcomeSubtype']
for f in toTransform: 
    lbl = preprocessing.LabelEncoder() 
    lbl.fit(list(train[f].values)) 
    train[f] = lbl.transform(list(train[f].values))
   
test = train[shapeTrain:shapeTrain+shapeTest]
train = train[0:shapeTrain]

lbl = preprocessing.LabelEncoder() 
lbl.fit(list(train['OutcomeType'].values))
train['OutcomeType'] = lbl.transform(list(train['OutcomeType'].values))

#set target columns
target = train['OutcomeType']
train = train.drop(['OutcomeType'],axis=1)
test = test.drop(['OutcomeType'],axis=1)

# %%
# target labels, seems to be correct
print lbl.inverse_transform([0, 1, 2, 3, 4])
# Out:
# ['Adoption' 'Died' 'Euthanasia' 'Return_to_owner' 'Transfer']

# %%
#pd.get_dummies(train['OutcomeSubtype']).head()

# %%
# train = train.append(test)

# train = pd.concat([train, pd.get_dummies(train['SexuponOutcome'])], axis=1, join_axes=[train.index])
# train = train.drop(['Unknown', 'SexuponOutcome'],axis=1)

# test = train[shapeTrain:shapeTrain+shapeTest]
# train = train[0:shapeTrain]

# %%
# train = train.append(test)

# train = pd.concat([train, pd.get_dummies(train['OutcomeSubtype'])], axis=1, join_axes=[train.index])
# train = train.drop(['Suffering', 'OutcomeSubtype'],axis=1)

# test = train[shapeTrain:shapeTrain + shapeTest]
# train = train[0:shapeTrain]

# %%
# train = train.append(test)

# train = pd.concat([train, pd.get_dummies(train['OutcomeType'])], axis=1, join_axes=[train.index])
# train = train.drop(['Unknown', 'OutcomeType'],axis=1)

# test = train[shapeTrain:shapeTrain + shapeTest]
# train = train[0:shapeTrain]

# %%
# converting   AgeuponOutcome (1 years) to days 
def age_to_days(item):
    # convert item to list if it is one string
    if type(item) is str:
        item = [item]
    if type(item) is float:
        item = '1 day'
        item = [item]
    ages_in_days = np.zeros(len(item))
    for i in range(len(item)):
        # check if item[i] is str
        if type(item[i]) is str:
            if 'day' in item[i]:
                ages_in_days[i] = int(item[i].split(' ')[0])
            if 'week' in item[i]:
                ages_in_days[i] = int(item[i].split(' ')[0])*7
            if 'month' in item[i]:
                ages_in_days[i] = int(item[i].split(' ')[0])*30
            if 'year' in item[i]:
                ages_in_days[i] = int(item[i].split(' ')[0])*365    
        else:
            # item[i] is not a string but a nan
            ages_in_days[i] = 0
    return ages_in_days

train['AgeuponOutcome'] = train['AgeuponOutcome'].map(lambda x: age_to_days(x)[0])
test['AgeuponOutcome'] = test['AgeuponOutcome'].map(lambda x: age_to_days(x)[0])

# %%
#splitting 
X_fit, X_eval, y_fit, y_eval= train_test_split(
    train, target, test_size=0.15, random_state=1
)
#training model
clf = xgb.XGBClassifier(max_depth=4, missing=np.NAN,
                        n_estimators=500, learning_rate=0.05, 
                        subsample=1, colsample_bytree=0.9, seed=2100,objective= 'multi:softprob')

clf.fit(X_fit, y_fit, early_stopping_rounds=35,  eval_metric="mlogloss", eval_set=[(X_eval, y_eval)])
# Out:
# Will train until validation_0 error hasn't decreased in 35 rounds.
# [0]	validation_0-mlogloss:1.514571
# [1]	validation_0-mlogloss:1.431074
# [2]	validation_0-mlogloss:1.355695
# [3]	validation_0-mlogloss:1.287897
# [4]	validation_0-mlogloss:1.232855
# [5]	validation_0-mlogloss:1.175692
# [6]	validation_0-mlogloss:1.125631
# [7]	validation_0-mlogloss:1.079275
# [8]	validation_0-mlogloss:1.036815
# [9]	validation_0-mlogloss:0.998959
# [10]	validation_0-mlogloss:0.961852
# [11]	validation_0-mlogloss:0.927253
# [12]	validation_0-mlogloss:0.894506
# [13]	validation_0-mlogloss:0.869924
# [14]	validation_0-mlogloss:0.844845
# [15]	validation_0-mlogloss:0.815055
# [16]	validation_0-mlogloss:0.786850
# [17]	validation_0-mlogloss:0.765829
# [18]	validation_0-mlogloss:0.742020
# [19]	validation_0-mlogloss:0.718012
# [20]	validation_0-mlogloss:0.696933
# [21]	validation_0-mlogloss:0.678713
# [22]	validation_0-mlogloss:0.662687
# [23]	validation_0-mlogloss:0.642933
# [24]	validation_0-mlogloss:0.626789
# [25]	validation_0-mlogloss:0.609506
# [26]	validation_0-mlogloss:0.594483
# [27]	validation_0-mlogloss:0.578918
# [28]	validation_0-mlogloss:0.563678
# [29]	validation_0-mlogloss:0.554180
# [30]	validation_0-mlogloss:0.542047
# [31]	validation_0-mlogloss:0.531007
# [32]	validation_0-mlogloss:0.519556
# [33]	validation_0-mlogloss:0.507755
# [34]	validation_0-mlogloss:0.498784
# [35]	validation_0-mlogloss:0.491279
# [36]	validation_0-mlogloss:0.483402
# [37]	validation_0-mlogloss:0.473925
# [38]	validation_0-mlogloss:0.464954
# [39]	validation_0-mlogloss:0.455873
# [40]	validation_0-mlogloss:0.447647
# [41]	validation_0-mlogloss:0.439190
# [42]	validation_0-mlogloss:0.431146
# [43]	validation_0-mlogloss:0.423455
# [44]	validation_0-mlogloss:0.416342
# [45]	validation_0-mlogloss:0.409321
# [46]	validation_0-mlogloss:0.402413
# [47]	validation_0-mlogloss:0.396185
# [48]	validation_0-mlogloss:0.390082
# [49]	validation_0-mlogloss:0.384550
# [50]	validation_0-mlogloss:0.378957
# [51]	validation_0-mlogloss:0.373617
# [52]	validation_0-mlogloss:0.368599
# [53]	validation_0-mlogloss:0.363436
# [54]	validation_0-mlogloss:0.359147
# [55]	validation_0-mlogloss:0.355008
# [56]	validation_0-mlogloss:0.350772
# [57]	validation_0-mlogloss:0.346823
# [58]	validation_0-mlogloss:0.342409
# [59]	validation_0-mlogloss:0.339168
# [60]	validation_0-mlogloss:0.335287
# [61]	validation_0-mlogloss:0.332758
# [62]	validation_0-mlogloss:0.329431
# [63]	validation_0-mlogloss:0.325771
# [64]	validation_0-mlogloss:0.322313
# [65]	validation_0-mlogloss:0.319741
# [66]	validation_0-mlogloss:0.316353
# [67]	validation_0-mlogloss:0.313111
# [68]	validation_0-mlogloss:0.310017
# [69]	validation_0-mlogloss:0.307484
# [70]	validation_0-mlogloss:0.304881
# [71]	validation_0-mlogloss:0.302201
# [72]	validation_0-mlogloss:0.299561
# [73]	validation_0-mlogloss:0.297349
# [74]	validation_0-mlogloss:0.295012
# [75]	validation_0-mlogloss:0.292981
# [76]	validation_0-mlogloss:0.290752
# [77]	validation_0-mlogloss:0.288913
# [78]	validation_0-mlogloss:0.286874
# [79]	validation_0-mlogloss:0.285150
# [80]	validation_0-mlogloss:0.283443
# [81]	validation_0-mlogloss:0.281777
# [82]	validation_0-mlogloss:0.280412
# [83]	validation_0-mlogloss:0.278682
# [84]	validation_0-mlogloss:0.277121
# [85]	validation_0-mlogloss:0.276037
# [86]	validation_0-mlogloss:0.274527
# [87]	validation_0-mlogloss:0.273490
# [88]	validation_0-mlogloss:0.272077
# [89]	validation_0-mlogloss:0.270902
# [90]	validation_0-mlogloss:0.269695
# [91]	validation_0-mlogloss:0.268778
# [92]	validation_0-mlogloss:0.267721
# [93]	validation_0-mlogloss:0.266579
# [94]	validation_0-mlogloss:0.265630
# [95]	validation_0-mlogloss:0.264628
# [96]	validation_0-mlogloss:0.263723
# [97]	validation_0-mlogloss:0.262688
# [98]	validation_0-mlogloss:0.261818
# [99]	validation_0-mlogloss:0.261040
# [100]	validation_0-mlogloss:0.260224
# [101]	validation_0-mlogloss:0.259389
# [102]	validation_0-mlogloss:0.258557
# [103]	validation_0-mlogloss:0.258107
# [104]	validation_0-mlogloss:0.257314
# [105]	validation_0-mlogloss:0.256570
# [106]	validation_0-mlogloss:0.255888
# [107]	validation_0-mlogloss:0.255243
# [108]	validation_0-mlogloss:0.254549
# [109]	validation_0-mlogloss:0.254002
# [110]	validation_0-mlogloss:0.253407
# [111]	validation_0-mlogloss:0.252994
# [112]	validation_0-mlogloss:0.252414
# [113]	validation_0-mlogloss:0.251876
# [114]	validation_0-mlogloss:0.251343
# [115]	validation_0-mlogloss:0.250853
# [116]	validation_0-mlogloss:0.250315
# [117]	validation_0-mlogloss:0.249881
# [118]	validation_0-mlogloss:0.249386
# [119]	validation_0-mlogloss:0.249071
# [120]	validation_0-mlogloss:0.248659
# [121]	validation_0-mlogloss:0.248238
# [122]	validation_0-mlogloss:0.247820
# [123]	validation_0-mlogloss:0.247494
# [124]	validation_0-mlogloss:0.247179
# [125]	validation_0-mlogloss:0.246832
# [126]	validation_0-mlogloss:0.246550
# [127]	validation_0-mlogloss:0.246154
# [128]	validation_0-mlogloss:0.245887
# [129]	validation_0-mlogloss:0.245578
# [130]	validation_0-mlogloss:0.245209
# [131]	validation_0-mlogloss:0.244859
# [132]	validation_0-mlogloss:0.244589
# [133]	validation_0-mlogloss:0.244293
# [134]	validation_0-mlogloss:0.243960
# [135]	validation_0-mlogloss:0.243650
# [136]	validation_0-mlogloss:0.243357
# [137]	validation_0-mlogloss:0.243151
# [138]	validation_0-mlogloss:0.242822
# [139]	validation_0-mlogloss:0.242628
# [140]	validation_0-mlogloss:0.242357
# [141]	validation_0-mlogloss:0.242100
# [142]	validation_0-mlogloss:0.241927
# [143]	validation_0-mlogloss:0.241716
# [144]	validation_0-mlogloss:0.241433
# [145]	validation_0-mlogloss:0.241237
# [146]	validation_0-mlogloss:0.241028
# [147]	validation_0-mlogloss:0.240806
# [148]	validation_0-mlogloss:0.240582
# [149]	validation_0-mlogloss:0.240344
# [150]	validation_0-mlogloss:0.240147
# [151]	validation_0-mlogloss:0.239955
# [152]	validation_0-mlogloss:0.239810
# [153]	validation_0-mlogloss:0.239609
# [154]	validation_0-mlogloss:0.239485
# [155]	validation_0-mlogloss:0.239348
# [156]	validation_0-mlogloss:0.239220
# [157]	validation_0-mlogloss:0.238997
# [158]	validation_0-mlogloss:0.238847
# [159]	validation_0-mlogloss:0.238658
# [160]	validation_0-mlogloss:0.238483
# [161]	validation_0-mlogloss:0.238296
# [162]	validation_0-mlogloss:0.238119
# [163]	validation_0-mlogloss:0.237942
# [164]	validation_0-mlogloss:0.237847
# [165]	validation_0-mlogloss:0.237745
# [166]	validation_0-mlogloss:0.237600
# [167]	validation_0-mlogloss:0.237463
# [168]	validation_0-mlogloss:0.237318
# [169]	validation_0-mlogloss:0.237159
# [170]	validation_0-mlogloss:0.237049
# [171]	validation_0-mlogloss:0.237000
# [172]	validation_0-mlogloss:0.236903
# [173]	validation_0-mlogloss:0.236788
# [174]	validation_0-mlogloss:0.236688
# [175]	validation_0-mlogloss:0.236559
# [176]	validation_0-mlogloss:0.236463
# [177]	validation_0-mlogloss:0.236389
# [178]	validation_0-mlogloss:0.236335
# [179]	validation_0-mlogloss:0.236234
# [180]	validation_0-mlogloss:0.236101
# [181]	validation_0-mlogloss:0.236008
# [182]	validation_0-mlogloss:0.235921
# [183]	validation_0-mlogloss:0.235827
# [184]	validation_0-mlogloss:0.235744
# [185]	validation_0-mlogloss:0.235606
# [186]	validation_0-mlogloss:0.235531
# [187]	validation_0-mlogloss:0.235444
# [188]	validation_0-mlogloss:0.235386
# [189]	validation_0-mlogloss:0.235305
# [190]	validation_0-mlogloss:0.235208
# [191]	validation_0-mlogloss:0.235092
# [192]	validation_0-mlogloss:0.235060
# [193]	validation_0-mlogloss:0.234972
# [194]	validation_0-mlogloss:0.234915
# [195]	validation_0-mlogloss:0.234818
# [196]	validation_0-mlogloss:0.234762
# [197]	validation_0-mlogloss:0.234689
# [198]	validation_0-mlogloss:0.234617
# [199]	validation_0-mlogloss:0.234506
# [200]	validation_0-mlogloss:0.234435
# [201]	validation_0-mlogloss:0.234297
# [202]	validation_0-mlogloss:0.234248
# [203]	validation_0-mlogloss:0.234189
# [204]	validation_0-mlogloss:0.234043
# [205]	validation_0-mlogloss:0.233978
# [206]	validation_0-mlogloss:0.233926
# [207]	validation_0-mlogloss:0.233872
# [208]	validation_0-mlogloss:0.233826
# [209]	validation_0-mlogloss:0.233735
# [210]	validation_0-mlogloss:0.233636
# [211]	validation_0-mlogloss:0.233585
# [212]	validation_0-mlogloss:0.233537
# [213]	validation_0-mlogloss:0.233429
# [214]	validation_0-mlogloss:0.233385
# [215]	validation_0-mlogloss:0.233298
# [216]	validation_0-mlogloss:0.233180
# [217]	validation_0-mlogloss:0.233148
# [218]	validation_0-mlogloss:0.233104
# [219]	validation_0-mlogloss:0.233110
# [220]	validation_0-mlogloss:0.232977
# [221]	validation_0-mlogloss:0.232966
# [222]	validation_0-mlogloss:0.232892
# [223]	validation_0-mlogloss:0.232802
# [224]	validation_0-mlogloss:0.232758
# [225]	validation_0-mlogloss:0.232731
# [226]	validation_0-mlogloss:0.232694
# [227]	validation_0-mlogloss:0.232669
# [228]	validation_0-mlogloss:0.232613
# [229]	validation_0-mlogloss:0.232567
# [230]	validation_0-mlogloss:0.232525
# [231]	validation_0-mlogloss:0.232474
# [232]	validation_0-mlogloss:0.232439
# [233]	validation_0-mlogloss:0.232404
# [234]	validation_0-mlogloss:0.232392
# [235]	validation_0-mlogloss:0.232349
# [236]	validation_0-mlogloss:0.232305
# [237]	validation_0-mlogloss:0.232270
# [238]	validation_0-mlogloss:0.232190
# [239]	validation_0-mlogloss:0.232198
# [240]	validation_0-mlogloss:0.232152
# [241]	validation_0-mlogloss:0.232116
# [242]	validation_0-mlogloss:0.232074
# [243]	validation_0-mlogloss:0.232094
# [244]	validation_0-mlogloss:0.232037
# [245]	validation_0-mlogloss:0.232011
# [246]	validation_0-mlogloss:0.232001
# [247]	validation_0-mlogloss:0.231983
# [248]	validation_0-mlogloss:0.231947
# [249]	validation_0-mlogloss:0.231909
# [250]	validation_0-mlogloss:0.231873
# [251]	validation_0-mlogloss:0.231847
# [252]	validation_0-mlogloss:0.231808
# [253]	validation_0-mlogloss:0.231793
# [254]	validation_0-mlogloss:0.231711
# [255]	validation_0-mlogloss:0.231710
# [256]	validation_0-mlogloss:0.231689
# [257]	validation_0-mlogloss:0.231647
# [258]	validation_0-mlogloss:0.231662
# [259]	validation_0-mlogloss:0.231629
# [260]	validation_0-mlogloss:0.231613
# [261]	validation_0-mlogloss:0.231603
# [262]	validation_0-mlogloss:0.231580
# [263]	validation_0-mlogloss:0.231482
# [264]	validation_0-mlogloss:0.231468
# [265]	validation_0-mlogloss:0.231427
# [266]	validation_0-mlogloss:0.231416
# [267]	validation_0-mlogloss:0.231399
# [268]	validation_0-mlogloss:0.231372
# [269]	validation_0-mlogloss:0.231342
# [270]	validation_0-mlogloss:0.231308
# [271]	validation_0-mlogloss:0.231276
# [272]	validation_0-mlogloss:0.231238
# [273]	validation_0-mlogloss:0.231228
# [274]	validation_0-mlogloss:0.231218
# [275]	validation_0-mlogloss:0.231197
# [276]	validation_0-mlogloss:0.231105
# [277]	validation_0-mlogloss:0.231073
# [278]	validation_0-mlogloss:0.231069
# [279]	validation_0-mlogloss:0.231036
# [280]	validation_0-mlogloss:0.231003
# [281]	validation_0-mlogloss:0.230980
# [282]	validation_0-mlogloss:0.230955
# [283]	validation_0-mlogloss:0.230916
# [284]	validation_0-mlogloss:0.230867
# [285]	validation_0-mlogloss:0.230831
# [286]	validation_0-mlogloss:0.230842
# [287]	validation_0-mlogloss:0.230860
# [288]	validation_0-mlogloss:0.230804
# [289]	validation_0-mlogloss:0.230791
# [290]	validation_0-mlogloss:0.230771
# [291]	validation_0-mlogloss:0.230736
# [292]	validation_0-mlogloss:0.230652
# [293]	validation_0-mlogloss:0.230663
# [294]	validation_0-mlogloss:0.230648
# [295]	validation_0-mlogloss:0.230629
# [296]	validation_0-mlogloss:0.230618
# [297]	validation_0-mlogloss:0.230600
# [298]	validation_0-mlogloss:0.230560
# [299]	validation_0-mlogloss:0.230533
# [300]	validation_0-mlogloss:0.230543
# [301]	validation_0-mlogloss:0.230566
# [302]	validation_0-mlogloss:0.230535
# [303]	validation_0-mlogloss:0.230482
# [304]	validation_0-mlogloss:0.230458
# [305]	validation_0-mlogloss:0.230442
# [306]	validation_0-mlogloss:0.230408
# [307]	validation_0-mlogloss:0.230410
# [308]	validation_0-mlogloss:0.230385
# [309]	validation_0-mlogloss:0.230378
# [310]	validation_0-mlogloss:0.230380
# [311]	validation_0-mlogloss:0.230361
# [312]	validation_0-mlogloss:0.230308
# [313]	validation_0-mlogloss:0.230299
# [314]	validation_0-mlogloss:0.230295
# [315]	validation_0-mlogloss:0.230296
# [316]	validation_0-mlogloss:0.230282
# [317]	validation_0-mlogloss:0.230264
# [318]	validation_0-mlogloss:0.230254
# [319]	validation_0-mlogloss:0.230251
# [320]	validation_0-mlogloss:0.230211
# [321]	validation_0-mlogloss:0.230268
# [322]	validation_0-mlogloss:0.230251
# [323]	validation_0-mlogloss:0.230244
# [324]	validation_0-mlogloss:0.230223
# [325]	validation_0-mlogloss:0.230225
# [326]	validation_0-mlogloss:0.230204
# [327]	validation_0-mlogloss:0.230220
# [328]	validation_0-mlogloss:0.230215
# [329]	validation_0-mlogloss:0.230183
# [330]	validation_0-mlogloss:0.230174
# [331]	validation_0-mlogloss:0.230172
# [332]	validation_0-mlogloss:0.230145
# [333]	validation_0-mlogloss:0.230151
# [334]	validation_0-mlogloss:0.230182
# [335]	validation_0-mlogloss:0.230180
# [336]	validation_0-mlogloss:0.230178
# [337]	validation_0-mlogloss:0.230157
# [338]	validation_0-mlogloss:0.230144
# [339]	validation_0-mlogloss:0.230127
# [340]	validation_0-mlogloss:0.230107
# [341]	validation_0-mlogloss:0.230113
# [342]	validation_0-mlogloss:0.230080
# [343]	validation_0-mlogloss:0.230051
# [344]	validation_0-mlogloss:0.230057
# [345]	validation_0-mlogloss:0.230065
# [346]	validation_0-mlogloss:0.230058
# [347]	validation_0-mlogloss:0.230036
# [348]	validation_0-mlogloss:0.230022
# [349]	validation_0-mlogloss:0.230006
# [350]	validation_0-mlogloss:0.229999
# [351]	validation_0-mlogloss:0.230001
# [352]	validation_0-mlogloss:0.230022
# [353]	validation_0-mlogloss:0.229984
# [354]	validation_0-mlogloss:0.229952
# [355]	validation_0-mlogloss:0.229957
# [356]	validation_0-mlogloss:0.229968
# [357]	validation_0-mlogloss:0.229943
# [358]	validation_0-mlogloss:0.229938
# [359]	validation_0-mlogloss:0.229949
# [360]	validation_0-mlogloss:0.229910
# [361]	validation_0-mlogloss:0.229895
# [362]	validation_0-mlogloss:0.229887
# [363]	validation_0-mlogloss:0.229876
# [364]	validation_0-mlogloss:0.229848
# [365]	validation_0-mlogloss:0.229868
# [366]	validation_0-mlogloss:0.229865
# [367]	validation_0-mlogloss:0.229865
# [368]	validation_0-mlogloss:0.229865
# [369]	validation_0-mlogloss:0.229829
# [370]	validation_0-mlogloss:0.229822
# [371]	validation_0-mlogloss:0.229819
# [372]	validation_0-mlogloss:0.229828
# [373]	validation_0-mlogloss:0.229779
# [374]	validation_0-mlogloss:0.229771
# [375]	validation_0-mlogloss:0.229750
# [376]	validation_0-mlogloss:0.229781
# [377]	validation_0-mlogloss:0.229767
# [378]	validation_0-mlogloss:0.229751
# [379]	validation_0-mlogloss:0.229740
# [380]	validation_0-mlogloss:0.229751
# [381]	validation_0-mlogloss:0.229745
# [382]	validation_0-mlogloss:0.229767
# [383]	validation_0-mlogloss:0.229755
# [384]	validation_0-mlogloss:0.229728
# [385]	validation_0-mlogloss:0.229724
# [386]	validation_0-mlogloss:0.229730
# [387]	validation_0-mlogloss:0.229741
# [388]	validation_0-mlogloss:0.229724
# [389]	validation_0-mlogloss:0.229695
# [390]	validation_0-mlogloss:0.229687
# [391]	validation_0-mlogloss:0.229674
# [392]	validation_0-mlogloss:0.229666
# [393]	validation_0-mlogloss:0.229674
# [394]	validation_0-mlogloss:0.229690
# [395]	validation_0-mlogloss:0.229709
# [396]	validation_0-mlogloss:0.229681
# [397]	validation_0-mlogloss:0.229706
# [398]	validation_0-mlogloss:0.229697
# [399]	validation_0-mlogloss:0.229666
# [400]	validation_0-mlogloss:0.229640
# [401]	validation_0-mlogloss:0.229632
# [402]	validation_0-mlogloss:0.229619
# [403]	validation_0-mlogloss:0.229589
# [404]	validation_0-mlogloss:0.229604
# [405]	validation_0-mlogloss:0.229629
# [406]	validation_0-mlogloss:0.229628
# [407]	validation_0-mlogloss:0.229613
# [408]	validation_0-mlogloss:0.229622
# [409]	validation_0-mlogloss:0.229609
# [410]	validation_0-mlogloss:0.229593
# [411]	validation_0-mlogloss:0.229581
# [412]	validation_0-mlogloss:0.229592
# [413]	validation_0-mlogloss:0.229584
# [414]	validation_0-mlogloss:0.229612
# [415]	validation_0-mlogloss:0.229630
# [416]	validation_0-mlogloss:0.229603
# [417]	validation_0-mlogloss:0.229585
# [418]	validation_0-mlogloss:0.229584
# [419]	validation_0-mlogloss:0.229594
# [420]	validation_0-mlogloss:0.229610
# [421]	validation_0-mlogloss:0.229582
# [422]	validation_0-mlogloss:0.229574
# [423]	validation_0-mlogloss:0.229568
# [424]	validation_0-mlogloss:0.229603
# [425]	validation_0-mlogloss:0.229640
# [426]	validation_0-mlogloss:0.229631
# [427]	validation_0-mlogloss:0.229651
# [428]	validation_0-mlogloss:0.229614
# [429]	validation_0-mlogloss:0.229580
# [430]	validation_0-mlogloss:0.229575
# [431]	validation_0-mlogloss:0.229526
# [432]	validation_0-mlogloss:0.229546
# [433]	validation_0-mlogloss:0.229527
# [434]	validation_0-mlogloss:0.229489
# [435]	validation_0-mlogloss:0.229483
# [436]	validation_0-mlogloss:0.229480
# [437]	validation_0-mlogloss:0.229509
# [438]	validation_0-mlogloss:0.229497
# [439]	validation_0-mlogloss:0.229510
# [440]	validation_0-mlogloss:0.229494
# [441]	validation_0-mlogloss:0.229508
# [442]	validation_0-mlogloss:0.229480
# [443]	validation_0-mlogloss:0.229480
# [444]	validation_0-mlogloss:0.229465
# [445]	validation_0-mlogloss:0.229427
# [446]	validation_0-mlogloss:0.229412
# [447]	validation_0-mlogloss:0.229389
# [448]	validation_0-mlogloss:0.229402
# [449]	validation_0-mlogloss:0.229384
# [450]	validation_0-mlogloss:0.229368
# [451]	validation_0-mlogloss:0.229409
# [452]	validation_0-mlogloss:0.229413
# [453]	validation_0-mlogloss:0.229418
# [454]	validation_0-mlogloss:0.229426
# [455]	validation_0-mlogloss:0.229427
# [456]	validation_0-mlogloss:0.229443
# [457]	validation_0-mlogloss:0.229442
# [458]	validation_0-mlogloss:0.229432
# [459]	validation_0-mlogloss:0.229411
# [460]	validation_0-mlogloss:0.229436
# [461]	validation_0-mlogloss:0.229411
# [462]	validation_0-mlogloss:0.229400
# [463]	validation_0-mlogloss:0.229393
# [464]	validation_0-mlogloss:0.229399
# [465]	validation_0-mlogloss:0.229367
# [466]	validation_0-mlogloss:0.229403
# [467]	validation_0-mlogloss:0.229414
# [468]	validation_0-mlogloss:0.229406
# [469]	validation_0-mlogloss:0.229389
# [470]	validation_0-mlogloss:0.229385
# [471]	validation_0-mlogloss:0.229403
# [472]	validation_0-mlogloss:0.229417
# [473]	validation_0-mlogloss:0.229409
# [474]	validation_0-mlogloss:0.229428
# [475]	validation_0-mlogloss:0.229428
# [476]	validation_0-mlogloss:0.229412
# [477]	validation_0-mlogloss:0.229399
# [478]	validation_0-mlogloss:0.229386
# [479]	validation_0-mlogloss:0.229383
# [480]	validation_0-mlogloss:0.229410
# [481]	validation_0-mlogloss:0.229434
# [482]	validation_0-mlogloss:0.229433
# [483]	validation_0-mlogloss:0.229431
# [484]	validation_0-mlogloss:0.229431
# [485]	validation_0-mlogloss:0.229441
# [486]	validation_0-mlogloss:0.229440
# [487]	validation_0-mlogloss:0.229448
# [488]	validation_0-mlogloss:0.229426
# [489]	validation_0-mlogloss:0.229459
# [490]	validation_0-mlogloss:0.229454
# [491]	validation_0-mlogloss:0.229479
# [492]	validation_0-mlogloss:0.229495
# [493]	validation_0-mlogloss:0.229476
# [494]	validation_0-mlogloss:0.229468
# [495]	validation_0-mlogloss:0.229477
# [496]	validation_0-mlogloss:0.229458
# [497]	validation_0-mlogloss:0.229437
# [498]	validation_0-mlogloss:0.229447
# [499]	validation_0-mlogloss:0.229477
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.9,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=4,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=2100, silent=True, subsample=1)

# %%
#printing result into file
k = clf.predict_proba(test)
#Adoption	Died	Euthanasia	Return_to_owner	Transfer
submission = pd.DataFrame({"ID":id_test, "Adoption":k[:,0], "Died":k[:,1],"Euthanasia":k[:,2],"Return_to_owner":k[:,3],"Transfer":k[:,4]})

cols = ['ID',"Adoption", "Died", "Euthanasia","Return_to_owner", "Transfer"]

submission = submission[cols]
submission.to_csv("submission_cats.csv", index=False)
